# %%
import pandas as pd

# %%
df=pd.read_csv("Project_18_B.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Outlet_Type']=le.fit_transform(df['Outlet_Type'])
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  Outlet_Type  \
# 0                          1999      Medium               Tier 1            1
# 1                          2009      Medium               Tier 3            2
# 2                          1999      Medium               Tier 1            1
# 3                          1998         NaN               Tier 3            0
# 4                          1987        High               Tier 3            1
# ...                         ...         ...                  ...          ...
# 8518                       1987        High               Tier 3            1
# 8519                       2002         NaN               Tier 2            1
# 8520                       2004       Small               Tier 2            1
# 8521                       2009      Medium               Tier 3            2
# 8522                       1997       Small               Tier 1            1
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 12 columns]

# %%
df['Item_Type']=le.fit_transform(df['Item_Type'])
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092            OUT049                       1999
# 1            14   48.2692            OUT018                       2009
# 2            10  141.6180            OUT049                       1999
# 3             6  182.0950            OUT010                       1998
# 4             9   53.8614            OUT013                       1987
# ...         ...       ...               ...                        ...
# 8518         13  214.5218            OUT013                       1987
# 8519          0  108.1570            OUT045                       2002
# 8520          8   85.1224            OUT035                       2004
# 8521         13  103.1332            OUT018                       2009
# 8522         14   75.4670            OUT046                       1997
#
#      Outlet_Size Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0         Medium               Tier 1            1          3735.1380
# 1         Medium               Tier 3            2           443.4228
# 2         Medium               Tier 1            1          2097.2700
# 3            NaN               Tier 3            0           732.3800
# 4           High               Tier 3            1           994.7052
# ...          ...                  ...          ...                ...
# 8518        High               Tier 3            1          2778.3834
# 8519         NaN               Tier 2            1           549.2850
# 8520       Small               Tier 2            1          1193.1136
# 8521      Medium               Tier 3            2          1845.5976
# 8522       Small               Tier 1            1           765.6700
#
# [8523 rows x 12 columns]

# %%
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#      Outlet_Size Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0         Medium               Tier 1            1          3735.1380
# 1         Medium               Tier 3            2           443.4228
# 2         Medium               Tier 1            1          2097.2700
# 3            NaN               Tier 3            0           732.3800
# 4           High               Tier 3            1           994.7052
# ...          ...                  ...          ...                ...
# 8518        High               Tier 3            1          2778.3834
# 8519         NaN               Tier 2            1           549.2850
# 8520       Small               Tier 2            1          1193.1136
# 8521      Medium               Tier 3            2          1845.5976
# 8522       Small               Tier 1            1           765.6700
#
# [8523 rows x 12 columns]

# %%
df['Item_Fat_Content']=le.fit_transform(df['Item_Fat_Content'])
df
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 3              FDX07       19.200                 2         0.000000
# 4              NCD19        8.930                 1         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 1         0.056783
# 8519           FDS36        8.380                 2         0.046982
# 8520           NCJ29       10.600                 1         0.035186
# 8521           FDN46        7.210                 2         0.145221
# 8522           DRG01       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#      Outlet_Size Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0         Medium               Tier 1            1          3735.1380
# 1         Medium               Tier 3            2           443.4228
# 2         Medium               Tier 1            1          2097.2700
# 3            NaN               Tier 3            0           732.3800
# 4           High               Tier 3            1           994.7052
# ...          ...                  ...          ...                ...
# 8518        High               Tier 3            1          2778.3834
# 8519         NaN               Tier 2            1           549.2850
# 8520       Small               Tier 2            1          1193.1136
# 8521      Medium               Tier 3            2          1845.5976
# 8522       Small               Tier 1            1           765.6700
#
# [8523 rows x 12 columns]

# %%
df['Item_Identifier']=le.fit_transform(df['Item_Identifier'])
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0             4  249.8092                  9                       1999
# 1            14   48.2692                  3                       2009
# 2            10  141.6180                  9                       1999
# 3             6  182.0950                  0                       1998
# 4             9   53.8614                  1                       1987
# ...         ...       ...                ...                        ...
# 8518         13  214.5218                  1                       1987
# 8519          0  108.1570                  7                       2002
# 8520          8   85.1224                  6                       2004
# 8521         13  103.1332                  3                       2009
# 8522         14   75.4670                  8                       1997
#
#      Outlet_Size Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0         Medium               Tier 1            1          3735.1380
# 1         Medium               Tier 3            2           443.4228
# 2         Medium               Tier 1            1          2097.2700
# 3            NaN               Tier 3            0           732.3800
# 4           High               Tier 3            1           994.7052
# ...          ...                  ...          ...                ...
# 8518        High               Tier 3            1          2778.3834
# 8519         NaN               Tier 2            1           549.2850
# 8520       Small               Tier 2            1          1193.1136
# 8521      Medium               Tier 3            2          1845.5976
# 8522       Small               Tier 1            1           765.6700
#
# [8523 rows x 12 columns]

# %%
df.drop('Outlet_Location_Type',axis=1,inplace=True)

# %%
df.drop('Outlet_Establishment_Year',axis=1,inplace=True)

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier Outlet_Size  Outlet_Type  \
# 0             4  249.8092                  9      Medium            1
# 1            14   48.2692                  3      Medium            2
# 2            10  141.6180                  9      Medium            1
# 3             6  182.0950                  0         NaN            0
# 4             9   53.8614                  1        High            1
# ...         ...       ...                ...         ...          ...
# 8518         13  214.5218                  1        High            1
# 8519          0  108.1570                  7         NaN            1
# 8520          8   85.1224                  6       Small            1
# 8521         13  103.1332                  3      Medium            2
# 8522         14   75.4670                  8       Small            1
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 10 columns]

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
df['Item_Weight']=df['Item_Weight'].fillna((df['Item_Weight'].mean()))
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier Outlet_Size  Outlet_Type  \
# 0             4  249.8092                  9      Medium            1
# 1            14   48.2692                  3      Medium            2
# 2            10  141.6180                  9      Medium            1
# 3             6  182.0950                  0         NaN            0
# 4             9   53.8614                  1        High            1
# ...         ...       ...                ...         ...          ...
# 8518         13  214.5218                  1        High            1
# 8519          0  108.1570                  7         NaN            1
# 8520          8   85.1224                  6       Small            1
# 8521         13  103.1332                  3      Medium            2
# 8522         14   75.4670                  8       Small            1
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 10 columns]

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode().values[0],inplace=True)
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier Outlet_Size  Outlet_Type  \
# 0             4  249.8092                  9      Medium            1
# 1            14   48.2692                  3      Medium            2
# 2            10  141.6180                  9      Medium            1
# 3             6  182.0950                  0      Medium            0
# 4             9   53.8614                  1        High            1
# ...         ...       ...                ...         ...          ...
# 8518         13  214.5218                  1        High            1
# 8519          0  108.1570                  7      Medium            1
# 8520          8   85.1224                  6       Small            1
# 8521         13  103.1332                  3      Medium            2
# 8522         14   75.4670                  8       Small            1
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 10 columns]

# %%
df['Outlet_Size']=le.fit_transform(df['Outlet_Size'])
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 1         0.016047
# 1                   8        5.920                 2         0.019278
# 2                 662       17.500                 1         0.016760
# 3                1121       19.200                 2         0.000000
# 4                1297        8.930                 1         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 1         0.056783
# 8519              897        8.380                 2         0.046982
# 8520             1357       10.600                 1         0.035186
# 8521              681        7.210                 2         0.145221
# 8522               50       14.800                 1         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Type  \
# 0             4  249.8092                  9            1            1
# 1            14   48.2692                  3            1            2
# 2            10  141.6180                  9            1            1
# 3             6  182.0950                  0            1            0
# 4             9   53.8614                  1            0            1
# ...         ...       ...                ...          ...          ...
# 8518         13  214.5218                  1            0            1
# 8519          0  108.1570                  7            1            1
# 8520          8   85.1224                  6            2            1
# 8521         13  103.1332                  3            1            2
# 8522         14   75.4670                  8            2            1
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Item_Identifier      0
# Item_Weight          0
# Item_Fat_Content     0
# Item_Visibility      0
# Item_Type            0
# Item_MRP             0
# Outlet_Identifier    0
# Outlet_Size          0
# Outlet_Type          0
# Item_Outlet_Sales    0
# dtype: int64

# %% [markdown]
# # EDA
# Scatterplot

# %%
import seaborn as sns

# %%
sns.scatterplot(x="Item_Weight" ,y="Item_Outlet_Sales",data=df)

# %%
sns.scatterplot(x="Item_Identifier" ,y="Item_Outlet_Sales",data=df)

# %%
sns.scatterplot(x="Item_Fat_Content" ,y="Item_Outlet_Sales",data=df)

# %%
sns.scatterplot(x="Outlet_Type" ,y="Item_Outlet_Sales",data=df)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                    Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier           1.000000     0.044518         -0.098114
# Item_Weight               0.044518     1.000000         -0.017331
# Item_Fat_Content         -0.098114    -0.017331          1.000000
# Item_Visibility          -0.025482    -0.012049          0.034042
# Item_Type                -0.017973     0.028015         -0.115958
# Item_MRP                  0.012853     0.024756         -0.000876
# Outlet_Identifier        -0.008602    -0.007975         -0.002357
# Outlet_Size               0.001389    -0.007225         -0.012058
# Outlet_Type              -0.001178    -0.000566         -0.004214
# Item_Outlet_Sales         0.002869     0.011550          0.009800
#
#                    Item_Visibility  Item_Type  Item_MRP  Outlet_Identifier  \
# Item_Identifier          -0.025482  -0.017973  0.012853          -0.008602
# Item_Weight              -0.012049   0.028015  0.024756          -0.007975
# Item_Fat_Content          0.034042  -0.115958 -0.000876          -0.002357
# Item_Visibility           1.000000  -0.035249 -0.001315          -0.100439
# Item_Type                -0.035249   1.000000  0.032651           0.001656
# Item_MRP                 -0.001315   0.032651  1.000000           0.003319
# Outlet_Identifier        -0.100439   0.001656  0.003319           1.000000
# Outlet_Size               0.069309  -0.001859  0.006059           0.504603
# Outlet_Type              -0.173468   0.003053 -0.001975           0.099873
# Item_Outlet_Sales        -0.128625   0.017048  0.567574           0.162325
#
#                    Outlet_Size  Outlet_Type  Item_Outlet_Sales
# Item_Identifier       0.001389    -0.001178           0.002869
# Item_Weight          -0.007225    -0.000566           0.011550
# Item_Fat_Content     -0.012058    -0.004214           0.009800
# Item_Visibility       0.069309    -0.173468          -0.128625
# Item_Type            -0.001859     0.003053           0.017048
# Item_MRP              0.006059    -0.001975           0.567574
# Outlet_Identifier     0.504603     0.099873           0.162325
# Outlet_Size           1.000000    -0.201483          -0.086182
# Outlet_Type          -0.201483     1.000000           0.401522
# Item_Outlet_Sales    -0.086182     0.401522           1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=8.5, linecolor="black", fmt= '.2f')

# %% [markdown]
# Correlation define :- Positive Correlation:-
#
#     1. Item_MRP = 0.57
#     2. Outlet_Type = 0.40
#     3. Outlet_Identifier = 0.16
# Negative Correlation:-
#     1. Outlet_Size  = -0.09
#     2. Item_Visibility = -0.13

# %% [markdown]
# # Describe Heatmap

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2), linewidth=2, annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("variables Summary")
plt.show()

# %%
df.drop('Item_Identifier',axis=1,inplace=True)

# %%
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Type  Item_Outlet_Sales
# 0                     9            1            1          3735.1380
# 1                     3            1            2           443.4228
# 2                     9            1            1          2097.2700
# 3                     0            1            0           732.3800
# 4                     1            0            1           994.7052
# ...                 ...          ...          ...                ...
# 8518                  1            0            1          2778.3834
# 8519                  7            1            1           549.2850
# 8520                  6            2            1          1193.1136
# 8521                  3            1            2          1845.5976
# 8522                  8            2            1           765.6700
#
# [8523 rows x 9 columns]

# %%
df.describe()
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility    Item_Type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean     12.857645          1.369354         0.066132     7.226681
# std       4.226124          0.644810         0.051598     4.209990
# min       4.555000          0.000000         0.000000     0.000000
# 25%       9.310000          1.000000         0.026989     4.000000
# 50%      12.857645          1.000000         0.053931     6.000000
# 75%      16.000000          2.000000         0.094585    10.000000
# max      21.350000          4.000000         0.328391    15.000000
#
#           Item_MRP  Outlet_Identifier  Outlet_Size  Outlet_Type  \
# count  8523.000000        8523.000000  8523.000000  8523.000000
# mean    140.992782           4.722281     1.170832     1.201220
# std      62.275067           2.837201     0.600327     0.796459
# min      31.290000           0.000000     0.000000     0.000000
# 25%      93.826500           2.000000     1.000000     1.000000
# 50%     143.012800           5.000000     1.000000     1.000000
# 75%     185.643700           7.000000     2.000000     1.000000
# max     266.888400           9.000000     2.000000     3.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# # Check data normalised or not

# %%
df.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %%
import itertools
cols= ['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
       'Item_MRP', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Type',
       'Item_Outlet_Sales']
length =len(cols)
cs=["r"]
fig = plt.figure(figsize=(13,20))

for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(4,2,j+1)
    ax= sns.distplot(df[i],color=k,rug=True)
    ax.set_facecolor=("w")
    plt.axvline(df[i].mean(),linestyle="dashed", label="mean", color="k")
    plt.legend(loc="best")
    plt.title(i, color="b")
    plt.xlabel("")
# Out:
# C:\Users\sagya\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8155e8f2e3b7> in <module>
#       8
#       9 for i,j,k in itertools.zip_longest(cols,range(length),cs):
# ---> 10     plt.subplot(4,2,j+1)
#      11     ax= sns.distplot(df[i],color=k,rug=True)
#      12     ax.set_facecolor=("w")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      63             else:
#      64                 if num < 1 or num > rows*cols:
# ---> 65                     raise ValueError(
#      66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#
# ValueError: num must be 1 <= num <= 8, not 9

# %%
df.hist(edgecolor='red', linewidth=1.5, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002031ECE5A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002031F07C340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002031F0A2790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002031F0CCC10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002031F0FA100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002031F131430>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002031F131520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002031F15F9D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002031F1C5250>]],
#       dtype=object)

# %%
df.skew()
# Out:
# Item_Weight          0.090561
# Item_Fat_Content     0.994824
# Item_Visibility      1.167091
# Item_Type            0.101655
# Item_MRP             0.127202
# Outlet_Identifier   -0.059861
# Outlet_Size         -0.087072
# Outlet_Type          0.927438
# Item_Outlet_Sales    1.177531
# dtype: float64

# %% [markdown]
# Skewness:
#
# 1.  Item_Visibility  =    1.167091
# 2.  Item_Outlet_Sales =   1.177531

# %% [markdown]
# # Data Transformation:
# Outliers Check

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='Blue',orient='v')
    plt.tight_layout()

# %% [markdown]
# # Remove Outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold =3
np.where(z>3)
# Out:
# (array([  49,   81,   83,  108,  130,  145,  151,  174,  199,  276,  304,
#          333,  339,  373,  396,  434,  456,  472,  489,  502,  521,  532,
#          615,  661,  694,  727,  753,  753,  809,  838,  854,  891,  935,
#          991,  997, 1009, 1010, 1034, 1090, 1124, 1133, 1138, 1159, 1183,
#         1209, 1254, 1272, 1291, 1311, 1324, 1372, 1433, 1434, 1450, 1496,
#         1501, 1506, 1512, 1542, 1549, 1560, 1575, 1576, 1615, 1617, 1644,
#         1651, 1684, 1723, 1753, 1769, 1805, 1827, 1841, 1859, 1998, 2062,
#         2088, 2109, 2111, 2122, 2143, 2168, 2173, 2216, 2223, 2238, 2251,
#         2293, 2324, 2331, 2438, 2439, 2445, 2516, 2535, 2552, 2569, 2586,
#         2613, 2660, 2678, 2728, 2776, 2855, 2895, 2905, 2971, 2973, 3011,
#         3017, 3083, 3087, 3098, 3154, 3206, 3225, 3234, 3241, 3242, 3243,
#         3286, 3335, 3367, 3399, 3407, 3458, 3474, 3480, 3488, 3491, 3497,
#         3509, 3540, 3545, 3582, 3602, 3667, 3709, 3720, 3750, 3757, 3767,
#         3884, 3993, 4006, 4019, 4083, 4163, 4219, 4245, 4289, 4290, 4346,
#         4349, 4382, 4393, 4408, 4415, 4463, 4530, 4656, 4674, 4676, 4680,
#         4681, 4772, 4789, 4865, 4888, 4941, 4961, 4991, 5031, 5047, 5054,
#         5065, 5133, 5146, 5150, 5177, 5185, 5202, 5223, 5287, 5315, 5374,
#         5401, 5417, 5467, 5500, 5539, 5550, 5577, 5611, 5619, 5633, 5732,
#         5734, 5752, 5784, 5795, 5799, 5812, 5837, 5880, 5891, 5946, 5977,
#         6000, 6008, 6012, 6132, 6134, 6176, 6179, 6268, 6334, 6344, 6357,
#         6370, 6409, 6462, 6468, 6486, 6536, 6537, 6540, 6541, 6576, 6606,
#         6622, 6674, 6729, 6786, 6803, 6843, 6886, 6903, 6993, 7001, 7005,
#         7016, 7076, 7088, 7107, 7121, 7146, 7147, 7188, 7191, 7200, 7215,
#         7236, 7250, 7256, 7278, 7302, 7308, 7318, 7343, 7353, 7388, 7496,
#         7499, 7535, 7558, 7560, 7562, 7603, 7609, 7690, 7693, 7703, 7712,
#         7722, 7744, 7745, 7751, 7752, 7816, 7826, 7866, 7910, 7930, 7944,
#         7949, 8004, 8039, 8085, 8143, 8194, 8201, 8215, 8233, 8245, 8273,
#         8345, 8387, 8432, 8447, 8517], dtype=int64),
#  array([2, 1, 2, 2, 8, 8, 1, 2, 1, 8, 8, 8, 1, 8, 1, 2, 8, 8, 1, 2, 2, 2,
#         1, 8, 8, 1, 1, 8, 8, 1, 2, 1, 8, 8, 8, 8, 1, 1, 1, 1, 1, 8, 2, 1,
#         1, 8, 2, 2, 2, 2, 1, 1, 2, 8, 2, 2, 8, 1, 1, 1, 2, 2, 1, 1, 1, 2,
#         2, 1, 1, 1, 1, 2, 2, 2, 8, 8, 1, 2, 8, 1, 2, 1, 1, 1, 8, 1, 8, 2,
#         8, 2, 1, 1, 2, 2, 8, 8, 1, 1, 2, 2, 1, 1, 2, 8, 2, 2, 1, 1, 1, 1,
#         2, 8, 8, 8, 8, 2, 1, 8, 1, 1, 1, 8, 1, 1, 2, 8, 2, 2, 1, 2, 1, 2,
#         1, 2, 1, 1, 1, 8, 8, 8, 2, 8, 2, 2, 2, 2, 1, 1, 1, 2, 1, 8, 1, 8,
#         8, 2, 1, 2, 1, 1, 2, 2, 2, 8, 1, 8, 8, 2, 1, 8, 2, 8, 8, 2, 1, 1,
#         8, 1, 1, 2, 8, 8, 1, 8, 2, 8, 2, 1, 1, 1, 8, 1, 8, 1, 1, 8, 1, 2,
#         2, 8, 1, 2, 8, 8, 2, 2, 2, 2, 8, 8, 2, 2, 1, 8, 1, 2, 1, 8, 1, 1,
#         1, 8, 1, 1, 1, 2, 8, 1, 8, 2, 8, 2, 2, 1, 2, 1, 1, 8, 2, 8, 1, 2,
#         8, 8, 2, 2, 2, 1, 1, 8, 8, 1, 2, 8, 2, 8, 2, 8, 1, 1, 8, 1, 2, 1,
#         2, 1, 2, 8, 8, 2, 8, 8, 1, 1, 1, 1, 2, 1, 1, 8, 8, 8, 2, 1, 8, 1,
#         2, 1, 8, 1, 1, 2, 8, 2, 1, 8, 2, 2, 1, 2, 8, 1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Type  Item_Outlet_Sales
# 0                     9            1            1          3735.1380
# 1                     3            1            2           443.4228
# 2                     9            1            1          2097.2700
# 3                     0            1            0           732.3800
# 4                     1            0            1           994.7052
# ...                 ...          ...          ...                ...
# 8518                  1            0            1          2778.3834
# 8519                  7            1            1           549.2850
# 8520                  6            2            1          1193.1136
# 8521                  3            1            2          1845.5976
# 8522                  8            2            1           765.6700
#
# [8222 rows x 9 columns]

# %%
df.shape
# Out:
# (8523, 9)

# %% [markdown]
# #Percentage loss of Data after removing outliers

# %%
percentage_loss=((8523-8222)/8523)*100
print(percentage_loss)
# Out:
# 3.5316203214830457

# %% [markdown]
# Removing Skewness…….

# %%
x=df.iloc[:,0:-1]

# %%
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0           9.300                 1         0.016047          4  249.8092
# 1           5.920                 2         0.019278         14   48.2692
# 2          17.500                 1         0.016760         10  141.6180
# 3          19.200                 2         0.000000          6  182.0950
# 4           8.930                 1         0.000000          9   53.8614
# ...           ...               ...              ...        ...       ...
# 8518        6.865                 1         0.056783         13  214.5218
# 8519        8.380                 2         0.046982          0  108.1570
# 8520       10.600                 1         0.035186          8   85.1224
# 8521        7.210                 2         0.145221         13  103.1332
# 8522       14.800                 1         0.044878         14   75.4670
#
#       Outlet_Identifier  Outlet_Size  Outlet_Type
# 0                     9            1            1
# 1                     3            1            2
# 2                     9            1            1
# 3                     0            1            0
# 4                     1            0            1
# ...                 ...          ...          ...
# 8518                  1            0            1
# 8519                  7            1            1
# 8520                  6            2            1
# 8521                  3            1            2
# 8522                  8            2            1
#
# [8523 rows x 8 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
df_new.skew()
# Out:
# Item_Weight          0.087821
# Item_Fat_Content     0.291106
# Item_Visibility      0.794506
# Item_Type            0.094578
# Item_MRP             0.139153
# Outlet_Identifier   -0.067611
# Outlet_Size         -0.089519
# Outlet_Type          0.957163
# Item_Outlet_Sales    0.877476
# dtype: float64

# %% [markdown]
# # Regressor Model Building

# %% [markdown]
# Linear Regression

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_t=sc.fit_transform(x)
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score

# %%
max_scr=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print("At Random_State",i,"The Model Perform well")
        print("At random_state:-",i)
        print("Training r2_score is:-",r2_score(y_train,pred_train)*100)
        print("Testing r2_score is:-",r2_score(y_test,pred_test)*100)
# Out:
# At Random_State 81 The Model Perform well
# At random_state:- 81
# Training r2_score is:- 51.80230201167346
# Testing r2_score is:- 51.800304075064275
# At Random_State 162 The Model Perform well
# At random_state:- 162
# Training r2_score is:- 51.78695590678021
# Testing r2_score is:- 51.78549185138923

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(x_t,y,random_state=81,test_size=0.20)

# %% [markdown]
# Random_State 81 The Model Perform well

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Regularization
# 1.Lasso

# %%
from sklearn.linear_model import Lasso
parameters ={'alpha' :[.0001, .001, .01, .1, 1, 10], 'random_state':list(range(1,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 1}

# %%
ls = Lasso(alpha=10,random_state=1)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls= ls.predict(x_test_b)

lss =r2_score(y_test_b,pred_ls)
for j in range(2,10):
    lsscore = cross_val_score(ls,x_t,y,cv=j)
    lsc= lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("R2_score is:-", lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 51.68658798917776
# R2_score is:- 51.75897331266736
#
#
# At cv:- 3
# Cross validation score is:- 51.663882371754696
# R2_score is:- 51.75897331266736
#
#
# At cv:- 4
# Cross validation score is:- 51.547005306408835
# R2_score is:- 51.75897331266736
#
#
# At cv:- 5
# Cross validation score is:- 51.623110320766386
# R2_score is:- 51.75897331266736
#
#
# At cv:- 6
# Cross validation score is:- 51.61981326149019
# R2_score is:- 51.75897331266736
#
#
# At cv:- 7
# Cross validation score is:- 51.661853629316
# R2_score is:- 51.75897331266736
#
#
# At cv:- 8
# Cross validation score is:- 51.62024998504607
# R2_score is:- 51.75897331266736
#
#
# At cv:- 9
# Cross validation score is:- 51.6334582125807
# R2_score is:- 51.75897331266736

# %%
print("At cv:-",2)
print("Cross validation score is:-",51.6865)
print("R2_Score is:-",51.7589)
# Out:
# At cv:- 2
# Cross validation score is:- 51.6865
# R2_Score is:- 51.7589

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error:')

print("Mean Absuolute Error:", mean_absolute_error(y_test_b,pred_ls))
print("Mean Squared Error:", mean_squared_error(y_test_b,pred_ls))
print("root mean squared Error:", np.sqrt(mean_squared_error(y_test_b,pred_ls)))
# Out:
# Error:
# Mean Absuolute Error: 867.4603179809178
# Mean Squared Error: 1392826.334371868
# root mean squared Error: 1180.1806363315186

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_ls, color='r')
plt.plot(y_test_b,y_test_b, color='g')
plt.xlabel('Actual Class', fontsize=14)
plt.ylabel('Predicted Class',fontsize=14)
plt.title('Lasso Regression', fontsize=18)
plt.show()

# %% [markdown]
# 2.Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
parameters ={'alpha':[.0001, .001, .01,.1 ,1],'fit_intercept':[True,False],'normalize':[True,False],'copy_X':[True,False],'tol':[1e-3], 'random_state':list(range(0,10))}
rd=Ridge()
clf =GridSearchCV(rd,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'copy_X': True, 'fit_intercept': True, 'normalize': True, 'random_state': 0, 'tol': 0.001}

# %%
rd = Ridge(alpha=0.001, copy_X=True, fit_intercept=True, normalize=True, random_state=0, tol=0.001)
rd.fit(x_train_b,y_train_b)
rd.score(x_train_b,y_train_b)
pred_rd= rd.predict(x_test_b)

rds =r2_score(y_test_b,pred_rd)
for j in range(2,10):
    rdscore = cross_val_score(rd,x_t,y,cv=j)
    rdc= rdscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",rdc*100)
    print("R2_score is:-", rds*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 51.661832777923976
# R2_score is:- 51.799847146300195
#
#
# At cv:- 3
# Cross validation score is:- 51.68682081244542
# R2_score is:- 51.799847146300195
#
#
# At cv:- 4
# Cross validation score is:- 51.51881691883645
# R2_score is:- 51.799847146300195
#
#
# At cv:- 5
# Cross validation score is:- 51.629917008976875
# R2_score is:- 51.799847146300195
#
#
# At cv:- 6
# Cross validation score is:- 51.60425300810413
# R2_score is:- 51.799847146300195
#
#
# At cv:- 7
# Cross validation score is:- 51.660650063858306
# R2_score is:- 51.799847146300195
#
#
# At cv:- 8
# Cross validation score is:- 51.60547542473891
# R2_score is:- 51.799847146300195
#
#
# At cv:- 9
# Cross validation score is:- 51.6295954893804
# R2_score is:- 51.799847146300195

# %%
print("At cv:-",3)
print("Cross validation score is:-",51.6868)
print("R2_Score is:-",51.7998)
# Out:
# At cv:- 3
# Cross validation score is:- 51.6868
# R2_Score is:- 51.7998

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error:')

print("Mean Absuolute Error:", mean_absolute_error(y_test_b,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test_b,pred_rd))
print("root mean squared Error:", np.sqrt(mean_squared_error(y_test_b,pred_rd)))
# Out:
# Error:
# Mean Absuolute Error: 868.9846079651993
# Mean Squared Error: 1391646.2153781424
# root mean squared Error: 1179.6805564974538

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_rd, color='r')
plt.plot(y_test_b,y_test_b, color='g')
plt.xlabel('Actual Class', fontsize=14)
plt.ylabel('Predicted Class',fontsize=14)
plt.title('Ridge Regression', fontsize=18)
plt.show()

# %% [markdown]
# # EnsambleTechnique

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
parameters ={'criterion':['mse','friedman_mse','mae'], 'splitter':['best','random']}
dt=DecisionTreeRegressor()
clf =GridSearchCV(dt,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'splitter': 'best'}

# %%
dt=DecisionTreeRegressor(criterion='mae', splitter='best')
dt.fit(x_train_b,y_train_b)
dt.score(x_train_b,y_train_b)
pred_dt= dt.predict(x_test_b)

dts =r2_score(y_test_b,pred_dt)
print("R2_score is:-", dts*100)

dtscore = cross_val_score(dt,x_t,y,cv=3)
dtc= dtscore.mean()
print("Cross validation score is:-",dtc*100)
print("\n")
# Out:
# R2_score is:- 17.77905658410843
# Cross validation score is:- 18.579661278292946

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_dt, color='r')
plt.plot(y_test_b,y_test_b, color='g')
plt.xlabel('Actual Class', fontsize=14)
plt.ylabel('Predicted Class',fontsize=14)
plt.title('DecisionTreeRegressior', fontsize=18)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor

# %%
parameters = {'loss': ['ls','lad', 'huber', 'quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse', 'mse']}
gbr=GradientBoostingRegressor()
clf =GridSearchCV(gbr,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'loss': 'ls', 'n_estimators': 50}

# %%
gbr=GradientBoostingRegressor(criterion='mse', loss='ls', n_estimators=50)
gbr.fit(x_train_b,y_train_b)
gbr.score(x_train_b,y_train_b)
pred_random= gbr.predict(x_test_b)

gbrs =r2_score(y_test_b,pred_random)
print("R2 score is:-",gbrs*100)

gbrscore = cross_val_score(gbr,x_t,y,cv=3)
gbrc= gbrscore.mean()
print("Cross validation score is:-",gbrc*100)
print("\n")
# Out:
# R2 score is:- 59.99159099875603
# Cross validation score is:- 59.77323810540708

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_random, color='r')
plt.plot(y_test_b,y_test_b, color='g')
plt.xlabel('Actual Class', fontsize=14)
plt.ylabel('Predicted Class',fontsize=14)
plt.title('Gradient Boost Regressorr', fontsize=18)
plt.show()

# %%
from sklearn.svm import SVR

# %%
parameters= {'kernel':['linear','poly','rbf','sigmoid']} #'gamma':['auto','scale']
sv= SVR()
clf=GridSearchCV(sv,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
parameters= {'gamma':['auto','scale']}
sv= SVR()
clf=GridSearchCV(sv,parameters)
clf.fit(x_train_b,y_train_b)

print(clf.best_params_)
# Out:
# {'gamma': 'scale'}

# %%
sv=SVR(kernel='linear', gamma='scale')
sv.fit(x_train_b,y_train_b)
sv.score(x_train_b,y_train_b)
pred_vector= sv.predict(x_test_b)

svs =r2_score(y_test_b,pred_vector)
print("R2 score is:-",svs*100)

svscore = cross_val_score(sv,x_t,y,cv=3)
svc= svscore.mean()
print("Cross validation score is:-",svc*100)
print("\n")
# Out:
# R2 score is:- 46.98617231814163
# Cross validation score is:- 46.46561921673127

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b, y=pred_random, color='r')
plt.plot(y_test_b,y_test_b, color='g')
plt.xlabel('Actual Class', fontsize=14)
plt.ylabel('Predicted Class',fontsize=14)
plt.title('SVR', fontsize=18)
plt.show()

# %% [markdown]
# # The Best Model is Gradient Boost Regressor  because of the difference between the percentage score of cross Val and r2_score is optimum

# %% [markdown]
# model saving

# %%
import pickle
filename= 'Project_18_Bigdatamart.pkl'
pickle.dump(gbr,open(filename,'wb'))

# %% [markdown]
# Conclusion

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([6439.6176, 1448.7808, 4288.4178, ..., 2553.343 , 2163.1842,
#        2553.343 ])

# %%
predicted=np.array(ls.predict(x_test))
predicted
# Out:
# array([4337.42171442, 2726.08849385, 3238.93372027, ..., 2835.46033909,
#        2082.90566424, 2805.9194539 ])

# %%
df_com=pd.DataFrame({"original":a,"predicted":predicted},index= range(len(a)))

# %%
df_com
# Out:
#        original    predicted
# 0     6439.6176  4337.421714
# 1     1448.7808  2726.088494
# 2     4288.4178  3238.933720
# 3     2085.2856  2710.969460
# 4     3870.9612  3124.979997
# ...         ...          ...
# 1700  3292.3810  2588.517325
# 1701  2994.7684  3236.087315
# 1702  2553.3430  2835.460339
# 1703  2163.1842  2082.905664
# 1704  2553.3430  2805.919454
#
# [1705 rows x 2 columns]

# %% [markdown]
# # from the above table the model is predicted the value with 55-60 percent accuracy.
